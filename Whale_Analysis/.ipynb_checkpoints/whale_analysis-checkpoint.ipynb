# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
#Setting precision for ease of viewing
#pd.set_option('precision', 2)

# %%
# Reading whale returns
whale_returns = Path("whale_returns.csv")
whale_returns_df = pd.read_csv(whale_returns, index_col="Date", parse_dates=True, infer_datetime_format=True)
whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_returns_df.dropna(inplace = True)

# Verify nulls have been dropped
whale_returns_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns = Path("algo_returns.csv")
algo_returns_df = pd.read_csv(algo_returns, index_col="Date", parse_dates=True, infer_datetime_format=True)
algo_returns_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls, investigate "inplace = True", without which the nulls do not drop.
algo_returns_df.dropna(inplace = True)
algo_returns_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500 = Path("sp500_history.csv")
sp500_df = pd.read_csv(sp500, index_col="Date", parse_dates=True, infer_datetime_format=True)
sp500_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Type
# Ran into error in conversion. Found that removing the $ symbol was necessary prior to float conversion.

sp500_df['Close'] = sp500_df['Close'].str.replace("$","")
sp500_df['Close'] = sp500_df['Close'].astype(float)
#correct index order
sp500_df = sp500_df.sort_index()
sp500_df.head()
# Out:
# C:\Users\Public\anaconda3\envs\dev\envs\dev\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93

# %%
# Calculate Daily Returns
sp500_df = sp500_df.pct_change()
sp500_df.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_df.dropna()
sp500_df.isnull().sum()
# Out:
# Close    1
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_df.rename(columns = {'Close':'S&P 500 Close'}, inplace = True)
sp500_df.head()
# Out:
#             S&P 500 Close
# Date
# 2012-10-01            NaN
# 2012-10-02       0.000872
# 2012-10-03       0.003624
# 2012-10-04       0.007174
# 2012-10-05      -0.000322

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns_df = pd.concat([whale_returns_df, algo_returns_df, sp500_df], axis="columns", join="inner")
combined_returns_df = combined_returns_df.sort_index()
combined_returns_df.index=combined_returns_df.index.date
combined_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  S&P 500 Close
# 2015-03-03 -0.000949      -0.004539
# 2015-03-04  0.002416      -0.004389
# 2015-03-05  0.004323       0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios, name Plot
combined_returns_df.plot(figsize=(20,10), title= 'Daily Returns: Portfolio vs Algorithmic vs S&P 500 Performance')
# Out:
# <AxesSubplot:title={'center':'Daily Returns: Portfolio vs Algorithmic vs S&P 500 Performance'}>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_return = (1 + combined_returns_df).cumprod()
# Plot cumulative returns
cumulative_return.plot(figsize=(20,10), title='Cumulative Returns: Portfolio vs Algorithmic vs S&P 500 Performance')
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns: Portfolio vs Algorithmic vs S&P 500 Performance'}>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
cumulative_return.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_returns_df.std()
daily_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
sp500_std = sp500_df.std()
sp500_std.head()
# Determine which portfolios are riskier than the S&P 500
daily_std = daily_std.sort_values(ascending = False)
daily_std.head(7)
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P 500 Close                  0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252)
annualized_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500 Close                  0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
combined_rolling_std = combined_returns_df.rolling(window=21).std().plot(figsize=(20,10), title='21 Days Rolling Std Dev')

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
portfolio_corr = combined_returns_df.corr()
# Display de correlation matrix
import seaborn as sns
sns.heatmap(portfolio_corr, vmin=0,vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance = combined_returns_df['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(combined_returns_df['S&P 500 Close'])

# Calculate variance of S&P 500
variance = combined_returns_df['S&P 500 Close'].rolling(window=60).var()

# Computing beta
beta = covariance / variance
beta = beta.dropna()
beta.sort_index()
beta
# Plot beta trend
beta.plot(figsize=(20,10), title='Beta Plot')
# Out:
# <AxesSubplot:title={'center':'Beta Plot'}>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_returns_df.ewm(halflife=21).std().plot(figsize=(20,10), title='Exponentially Weighted Moving Avg, 21 Day Halflife')
# Out:
# <AxesSubplot:title={'center':'Exponentially Weighted Moving Avg, 21 Day Halflife'}>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharp = combined_returns_df.mean()*252 / combined_returns_df.std()*np.sqrt(252)

# %%
# Visualize the sharpe ratios as a bar plot
sharp.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algorithmic portfolio one is comparable with the others while Algorithmic portfolio 2 outperforms all others by far.
# All portfolios have similar risk as per standard deviation plots.
# Algorithmic portfolios one and two have negligible correleation.
# There is no doubt that the algorithmic strategies outperform, even the "Whales", by far.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
aapl = Path("aapl_historical.csv")
aapl_df = pd.read_csv(aapl, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
aapl_df.rename(columns = {'NOCP':'AAPL'}, inplace = True)
aapl_df = aapl_df.drop(['Symbol'], axis=1)
aapl_df = aapl_df.sort_index()
aapl_df.head()
# Out:
#               AAPL
# Trade DATE
# 2018-05-11  188.59
# 2018-05-14  188.15
# 2018-05-15  186.44
# 2018-05-16  188.18
# 2018-05-17  186.99

# %%
# Reading data from 2nd stock
goog = Path("goog_historical.csv")
goog_df = pd.read_csv(goog, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
goog_df.rename(columns = {'NOCP':'GOOG'}, inplace = True)
goog_df = goog_df.drop(['Symbol'], axis=1)
goog_df = goog_df.sort_index()
goog_df.head()
# Out:
#                GOOG
# Trade DATE
# 2018-05-11  1098.26
# 2018-05-14  1100.20
# 2018-05-15  1079.23
# 2018-05-16  1081.77
# 2018-05-17  1078.59

# %%
# Reading data from 3rd stock
cost = Path("cost_historical.csv")
cost_df = pd.read_csv(cost, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
cost_df.rename(columns = {'NOCP':'COST'}, inplace = True)
cost_df = cost_df.drop(['Symbol'], axis = 1)
cost_df = cost_df.sort_index()
cost_df.head()
# Out:
#               COST
# Trade DATE
# 2018-05-11  195.76
# 2018-05-14  195.88
# 2018-05-15  195.48
# 2018-05-16  198.71
# 2018-05-17  199.60

# %%
# Combine all stocks in a single DataFrame
combined_stocks_df = pd.concat([aapl_df, goog_df, cost_df], axis="columns", join="inner")
combined_stocks_df.head()
# Out:
#               AAPL     GOOG    COST
# Trade DATE
# 2018-05-11  188.59  1098.26  195.76
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-17  186.99  1078.59  199.60

# %%
# Reset Date index
combined_stocks_df.index=combined_stocks_df.index.date
combined_stocks_df.head()
# Out:
#               AAPL     GOOG    COST
# 2018-05-11  188.59  1098.26  195.76
# 2018-05-14  188.15  1100.20  195.88
# 2018-05-15  186.44  1079.23  195.48
# 2018-05-16  188.18  1081.77  198.71
# 2018-05-17  186.99  1078.59  199.60

# %%
# Calculate daily returns
combined_stocks_df = combined_stocks_df.pct_change()
# Drop NAs
combined_stocks_df.dropna(inplace = True)
# Display sample data
combined_stocks_df.head()
# Out:
#                 AAPL      GOOG      COST
# 2018-05-14 -0.002333  0.001766  0.000613
# 2018-05-15 -0.009088 -0.019060 -0.002042
# 2018-05-16  0.009333  0.002354  0.016523
# 2018-05-17 -0.006324 -0.002940  0.004479
# 2018-05-18 -0.003637 -0.011339 -0.003206

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
weighted_return = combined_stocks_df.dot(weights)
# Display sample data
weighted_return.head()
# Out:
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
overall_combination = pd.concat([combined_stocks_df, combined_returns_df], axis="columns", join="inner")

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
overall_combination.dropna(inplace = True)
overall_combination.head()
# Out:
#                 AAPL      GOOG      COST  SOROS FUND MANAGEMENT LLC  \
# 2018-05-14 -0.002333  0.001766  0.000613                   0.000000
# 2018-05-15 -0.009088 -0.019060 -0.002042                  -0.000726
# 2018-05-16  0.009333  0.002354  0.016523                   0.008637
# 2018-05-17 -0.006324 -0.002940  0.004479                  -0.001955
# 2018-05-18 -0.003637 -0.011339 -0.003206                  -0.004357
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# 2018-05-14            0.000000                     0.000000
# 2018-05-15           -0.001409                    -0.003189
# 2018-05-16            0.006244                     0.005480
# 2018-05-17            0.002524                    -0.006267
# 2018-05-18           -0.002672                    -0.012832
#
#             BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  S&P 500 Close
# 2018-05-14                0.000000  0.000915  0.001635       0.000884
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
com_daily_std = overall_combination.std()
com_ann_std  =com_daily_std * np.sqrt(252)
con_ann_std = com_ann_std.sort_values(ascending = False)
con_ann_std.dropna(inplace=True)
con_ann_std.head(10)
# Out:
# AAPL                           0.296951
# GOOG                           0.255500
# BERKSHIRE HATHAWAY INC         0.247155
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# COST                           0.212034
# S&P 500 Close                  0.152054
# SOROS FUND MANAGEMENT LLC      0.146675
# Algo 2                         0.139556
# Algo 1                         0.133704
# PAULSON & CO.INC.              0.116732
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate and plot rolling standard deviation
overall_combination.rolling(window=21).std().plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
overall_corr = overall_combination.corr()
sns.heatmap(overall_corr, vmin=0, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
cov2 = overall_combination['GOOG'].rolling(window=60).cov(overall_combination['S&P 500 Close'])
var2 = overall_combination['S&P 500 Close'].rolling(window=60).var()
beta2 = cov2 / var2
beta2.plot(figsize=(20,10), title='Beta Plot')
# Out:
# <AxesSubplot:title={'center':'Beta Plot'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharp2 = overall_combination.mean() * 252 / overall_combination.std()*np.sqrt(252)

# %%
# Visualize the sharpe ratios as a bar plot
sharp2.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
Apple, Google, and Costco all perform well. However, they seem to be more volatile than the first algorithmic portfolio, as well as providing lesser returns. These are great stocks to have, but
do not make as great a portfolio as does our algorithm.
# Out:
#   File "C:\Users\Johnathan Overton\AppData\Local\Temp\ipykernel_17048\1547534605.py", line 1
#     Apple, Google, and Costco all perform well. However, they seem to be more volatile than the first algorithmic portfolio, as well as providing lesser returns. These are great stocks to have, but
#                      ^
# SyntaxError: invalid syntax
